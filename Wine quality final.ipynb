# %%
import pandas as pd

# %%
r_w = pd.read_csv("winequality-red.csv", sep = ";")
w_w = pd.read_csv("winequality-white.csv", sep = ";")

# %%
r_w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
w_w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
#     What chemical characteristics are most important in predicting the quality of wine?
#
#     Is a certain type of wine (red or white) associated with higher quality?
#
#     Do wines with higher alcoholic content receive better ratings?
#
#     Do sweeter wines (more residual sugar) receive better ratings?
#
#     What level of acidity is associated with the highest quality?

# %%
r_w["quality"].max()
# Out:
# 8

# %%
df_r = r_w[r_w["quality"] == 8]

# %%
df_r
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 498            10.7              0.35         0.53             2.6      0.070
# 588             5.0              0.42         0.24             2.0      0.060
# 828             7.8              0.57         0.09             2.3      0.065
# 1061            9.1              0.40         0.50             1.8      0.071
# ...

# %%
w_w["quality"].max()
# Out:
# 9

# %%
df_w = w_w[w_w["quality"] >= 9]

# %%
df_w
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 774             9.1              0.27         0.45            10.6      0.035
# 820             6.6              0.36         0.29             1.6      0.021
# 827             7.4              0.24         0.36             2.0      0.031
# 876             6.9              0.36         0.34             4.2      0.018
# 1605            7.1              0.26         0.49             2.2      0.032
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 774                  28.0                 124.0  0.99700  3.20       0.46
# 820                  24.0                  85.0  0.98965  3.41       0.61
# 827                  27.0                 139.0  0.99055  3.28       0.48
# 876                  57.0                 119.0  0.98980  3.28       0.36
# 1605                 31.0                 113.0  0.99030  3.37       0.42
#
#       alcohol  quality
# 774      10.4        9
# ...

# %%
w_w.shape
# Out:
# (4898, 12)

# %%
r_w.shape
# Out:
# (1599, 12)

# %%
w_w.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
r_w.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(w_w.duplicated().sum())
# Out:
# 937

# %%
r_w.nunique().value_counts().sum()
# Out:
# 12

# %%
r_w.quality.nunique()
# Out:
# 6

# %%
rn_w = pd.unique(r_w.sum()).sum()
rn_w
# Out:
# 152084.78194000002

# %%
w_w.quality.nunique()
# Out:
# 7

# %%
r_w.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
color_red = "red"
color_white = "white"

# %%
r_w['color'] = color_red
w_w['color'] = color_white

# %%
r_w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
w_w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
frames = [r_w, w_w]
wine_df = pd.concat(frames)
wine_df.head(2000)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 396            8.2              0.28         0.42             1.8      0.031
# 397            6.3              0.20         0.40             1.5      0.037
# 398            5.9              0.26         0.27            18.2      0.048
# 399            6.4              0.19         0.42             2.9      0.032
# 400            6.3              0.20         0.40             1.5      0.037
#
# ...

# %%
wine_df.to_csv("winequality_edited.csv", index = False)

# %%
wine_df.shape
# Out:
# (6497, 13)

# %% [markdown]
# - Based on histograms of columns in this dataset, which of the following feature variables appear skewed to the right? Fixed Acidity, Total Sulfur Dioxide, pH, Alcohol
#
# - Based on scatterplots of quality against different feature variables, which of the following is most likely to have a positive impact on quality? Volatile Acidity, Residual Sugar, pH, Alcohol

# %%
wine_df['fixed acidity'].hist()
# Out:
# <AxesSubplot:>

# %%
wine_df['total sulfur dioxide'].hist()
# Out:
# <AxesSubplot:>

# %%
wine_df['pH'].hist()
# Out:
# <AxesSubplot:>

# %%
wine_df['alcohol'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wine_df.plot(x="volatile acidity", y="quality", kind="scatter")
wine_df.plot(x="residual sugar", y="quality", kind="scatter")
wine_df.plot(x="pH", y="quality", kind="scatter")
wine_df.plot(x="alcohol", y="quality", kind="scatter")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
wine_df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# ...

# %%
wine_df.groupby(['quality', 'color'], as_index=False).mean()
# Out:
#     quality  color  fixed acidity  volatile acidity  citric acid  \
# 0         3    red       8.360000          0.884500     0.171000
# 1         3  white       7.600000          0.333250     0.336000
# 2         4    red       7.779245          0.693962     0.174151
# 3         4  white       7.129448          0.381227     0.304233
# 4         5    red       8.167254          0.577041     0.243686
# 5         5  white       6.933974          0.302011     0.337653
# 6         6    red       8.347179          0.497484     0.273824
# 7         6  white       6.837671          0.260564     0.338025
# 8         7    red       8.872362          0.403920     0.375176
# 9         7  white       6.734716          0.262767     0.325625
# 10        8    red       8.566667          0.423333     0.391111
# 11        8  white       6.657143          0.277400     0.326514
# 12        9  white       7.420000          0.298000     0.386000
#
# ...

# %%
wine_df.groupby(['quality', 'color'], as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %%
wine_df['pH'].describe()
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %% [markdown]
#     High: Lowest 25% of pH values
#     Moderately High: 25% - 50% of pH values
#     Medium: 50% - 75% of pH values
#     Low: 75% - max pH value

# %%
bin_edges = [2.72, 3.11, 3.21, 3.2185, 4.01]
bin_names = ['high','mod_high','medium','low']

# %%
# Creates acidity_levels column
wine_df['acidity levels'] = pd.cut(wine_df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity levels
# 0      9.4        5   red            low
# ...

# %%
# Save changes for the next section
wine = wine_df.copy()
wine.to_csv('winequality_edited.csv', index=False)

# %% [markdown]
# ### Lesson 15
#
# - Q1: Do wines with higher alcoholic content receive better ratings?
#
# To answer this question, use query to create two groups of wine samples:
#
#     Low alcohol (samples with an alcohol content less than the median)
#     High alcohol (samples with an alcohol content greater than or equal to the median)
#
# Then, find the mean quality rating of each group.
#
# - Q2: Do sweeter wines (more residual sugar) receive better ratings?
#
# Similarly, use the median to split the samples into two groups by residual sugar and find the mean quality rating of each group.

# %%
wine_df['alcohol'].median()
# Out:
# 10.3

# %%
wine_df.query('alcohol < 10.3')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# ...             ...               ...          ...             ...        ...
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4892            6.5             0.230         0.38            1.30      0.032
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
#
# ...

# %%
wine_df.query('alcohol >= 10.3')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 16              8.5             0.280         0.56             1.8      0.092
# 31              6.9             0.685         0.00             2.5      0.105
# 36              7.8             0.600         0.14             2.4      0.086
# ...             ...               ...          ...             ...        ...
# 4890            6.1             0.340         0.29             2.2      0.036
# 4891            5.7             0.210         0.32             0.9      0.038
# 4893            6.2             0.210         0.29             1.6      0.039
# 4896            5.5             0.290         0.30             1.1      0.022
# 4897            6.0             0.210         0.38             0.8      0.020
#
# ...

# %%
wine_df.query('alcohol < 10.3').mean()
# Out:
# fixed acidity             7.299496
# volatile acidity          0.355777
# citric acid               0.315244
# residual sugar            6.955461
# chlorides                 0.064714
# free sulfur dioxide      33.355052
# total sulfur dioxide    129.736544
# density                   0.996455
# pH                        3.201350
# sulphates                 0.530850
# alcohol                   9.485463
# quality                   5.475921
# dtype: float64

# %%
wine_df.query('alcohol >= 10.3').mean()
# Out:
# fixed acidity             7.134744
# volatile acidity          0.324248
# citric acid               0.321877
# residual sugar            3.996145
# chlorides                 0.047727
# free sulfur dioxide      27.817470
# total sulfur dioxide    102.355271
# density                   0.993014
# pH                        3.234913
# sulphates                 0.531669
# alcohol                  11.454793
# quality                   6.146084
# dtype: float64

# %% [markdown]
# Q2. Do sweeter wines (more residual sugar) receive better ratings?
#
# Similarly, use the median to split the samples into two groups by residual sugar and find the mean quality rating of each group.

# %%
wine_df['residual sugar'].median()
# Out:
# 3.0

# %%
wine_df[wine_df['residual sugar'] >= 3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36            6.10      0.071
# 11              7.5             0.500         0.36            6.10      0.071
# 14              8.9             0.620         0.18            3.80      0.176
# 15              8.9             0.620         0.19            3.90      0.170
# 18              7.4             0.590         0.08            4.40      0.086
# ...             ...               ...          ...             ...        ...
# 4884            6.5             0.330         0.38            8.30      0.048
# 4885            6.6             0.340         0.40            8.10      0.046
# 4886            6.2             0.210         0.28            5.70      0.028
# 4889            4.9             0.235         0.27           11.75      0.030
# 4894            6.6             0.320         0.36            8.00      0.047
#
# ...

# %%
wine_df[wine_df['residual sugar'] < 3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4892            6.5              0.23         0.38             1.3      0.032
# 4893            6.2              0.21         0.29             1.6      0.039
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_df[wine_df['residual sugar'] >= 3].mean()
# Out:
# fixed acidity             7.021927
# volatile acidity          0.305914
# citric acid               0.335881
# residual sugar            9.012492
# chlorides                 0.050215
# free sulfur dioxide      37.168807
# total sulfur dioxide    142.713609
# density                   0.995590
# pH                        3.179248
# sulphates                 0.497532
# alcohol                  10.259234
# quality                   5.827829
# dtype: float64

# %%
wine_df[wine_df['residual sugar'] < 3].mean()
# Out:
# fixed acidity            7.411264
# volatile acidity         0.373867
# citric acid              0.301156
# residual sugar           1.826418
# chlorides                0.061931
# free sulfur dioxide     23.793306
# total sulfur dioxide    88.416176
# density                  0.993791
# pH                       3.258277
# sulphates                0.565454
# alcohol                 10.727466
# quality                  5.808801
# dtype: float64

# %% [markdown]
# # Creating a Bar Chart Using Matplotlib

# %% [markdown]
# ### #1: Do wines with higher alcoholic content receive better ratings?
# Create a bar chart with one bar for low alcohol and one bar for high alcohol wine samples. This first one is filled out for you.

# %%
# Use query to select each group and get its mean quality
median = wine_df['alcohol'].median()
low = wine_df.query('alcohol < {}'.format(median))
high = wine_df.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
# Create a bar chart with proper labels
locations = [1, 2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ### #2: Do sweeter wines receive higher ratings?
# Create a bar chart with one bar for low residual sugar and one bar for high residual sugar wine samples.

# %%
wine_df.rename(columns={'residual sugar':'residual_sugar'}, inplace=True)

# %%
# Use query to select each group and get its mean quality
median = wine_df['residual_sugar'].median()
low = wine_df.query('residual_sugar < {}'.format(median))
high = wine_df.query('residual_sugar >= {}'.format(median))

low = wine_df.query('residual_sugar < 3')
high = wine_df.query('residual_sugar >= 3')

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# if we didn't change the name from residual sugar to residual_sugar the query method won't work 
    # and we will use the old way of filtering
# mean_quality_low = wine_df[wine_df['residual sugar'] < 3].mean()

# and this way will cause an error when we try plotting the function

# %%
# mean_quality_high = wine_df[wine_df['residual sugar'] >= 3].mean()

# %%
# Create a bar chart with proper labels
locations = [1, 2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low', 'High']

# %%
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Residual Sugar')
plt.xlabel('Residual Sugar')
plt.ylabel('Average Quality Rating')
# Out:
# Text(0, 0.5, 'Average Quality Rating')

# %% [markdown]
# ### #3: What level of acidity receives the highest average rating?
# Create a bar chart with a bar for each of the four acidity levels.

# %%
wine_df.rename(columns={'acidity levels':'acidity_levels'}, inplace=True)

# %%
# Use groupby to get the mean quality for each acidity level
acidity_level_quality_means = wine_df.groupby('acidity_levels').quality.mean()
acidity_level_quality_means
# Out:
# acidity_levels
# high        5.783343
# mod_high    5.784540
# medium           NaN
# low         5.855230
# Name: quality, dtype: float64

# %%
# Create a bar chart with proper labels
locations = [4, 1, 2, 3]  # reorder values above to go from low to high
heights = acidity_level_quality_means

# labels = ['Low', 'Medium', 'Moderately High', 'High']
labels = acidity_level_quality_means.index.str.replace('_', ' ').str.title() # alternative to commented out line above

plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Acidity Level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Rating')
# Out:
# Text(0, 0.5, 'Average Quality Rating')

# %% [markdown]
# ### Bonus: Create a line plot for the data in #3
# You can use pyplot's [plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) function for this.

# %%
import matplotlib.pyplot
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')

# %%
matplotlib.pyplot.plot(locations, heights, color='red', marker='o', linestyle='dotted',linewidth=2, markersize=6)

# %% [markdown]
# Compare this with the bar chart. How might showing this visual instead of the bar chart affect someone's conclusion about this data?

# %% [markdown]
# At bar chart it might be not showing the difference between the 4 levels of acidity (they might be close) but at the other function .plot() there's a significant difference

# %%
# get counts for each rating and color
color_counts = wine_df.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_totals = wine_df.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportions = color_counts['red'] / color_totals['red']
# if we didn't add this value "red_proportions['9'] = 0" an error appears when we try to plot proportions
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
red_proportions['9'] = 0
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
# get proportions by dividing white rating counts by total # of white samples
white_proportions = color_counts['white'] / color_totals['white']
white_proportions
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %% [markdown]
# ### Plot proportions on a bar chart
# Set the x coordinate location for each rating group and and width of each bar.

# %%
ind = np.arange(len(red_proportions))  # the x locations for the groups
width = 0.35       # the width of the bars

# %% [markdown]
# Now let’s create the plot.

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()
